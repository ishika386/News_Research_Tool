# %% [markdown]
# ## Document Loaders In LangChain

# %% [markdown]
# #### TextLoader

# %%
from langchain_classic.document_loaders import TextLoader

loader = TextLoader("nvda_news_1.txt")
loader.load()
# Out:
# [Document(metadata={'source': 'nvda_news_1.txt'}, page_content="The stock of NVIDIA Corp (NASDAQ:NVDA) experienced a daily loss of -3.56% and a 3-month gain of 32.35%. With an Earnings Per Share (EPS) (EPS) of $1.92, the question arises: is the stock significantly overvalued? This article aims to provide a detailed valuation analysis of NVIDIA, offering insights into its financial strength, profitability, growth, and more. We invite you to delve into this comprehensive analysis.\n\nCompany Overview\nWarning! GuruFocus has detected 10 Warning Signs with NVDA. Click here to check it out.\n\nNVDA 30-Year Financial Data\n\nThe intrinsic value of NVDA\n\n\nNVIDIA Corp (NASDAQ:NVDA) is a leading designer of discrete graphics processing units that enhance the experience on computing platforms. The firm's chips are widely used in various end markets, including PC gaming and data centers. In recent years, NVIDIA has broadened its focus from traditional PC graphics applications such as gaming to more complex and favorable opportunities, including artificial intelligence and autonomous driving, leveraging the high-performance capabilities of its products.\n\nCurrently, NVIDIA's stock price stands at $418.01, significantly higher than the GF Value of $310.28, indicating the stock might be overvalued. With a market cap of $1 trillion, the valuation seems steep. The following analysis aims to delve deeper into the company's value.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nUnderstanding the GF Value\nThe GF Value is a unique measure of the intrinsic value of a stock, calculated based on historical trading multiples, a GuruFocus adjustment factor, and future business performance estimates. If the stock price is significantly above the GF Value Line, it is overvalued, and its future return is likely to be poor. Conversely, if it is significantly below the GF Value Line, its future return will likely be higher.\n\nAccording to GuruFocus Value calculation, NVIDIA (NASDAQ:NVDA) appears to be significantly overvalued. The stock's current price of $418.01 per share and the market cap of $1 trillion further strengthen this assumption.\n\nGiven that NVIDIA is significantly overvalued, the long-term return of its stock is likely to be much lower than its future business growth.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nLink: These companies may deliver higher future returns at reduced risk.\n\nFinancial Strength of NVIDIA\nExamining the financial strength of a company is crucial before investing in its stock. Companies with poor financial strength pose a higher risk of permanent loss. NVIDIA's cash-to-debt ratio of 1.27 is worse than 58.04% of companies in the Semiconductors industry. However, NVIDIA's overall financial strength is 8 out of 10, indicating a strong financial position.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nProfitability and Growth\nConsistent profitability over the long term reduces the risk for investors. NVIDIA, with its profitability ranking of 10 out of 10, has been profitable for the past 10 years. The company's operating margin of 17.37% ranks better than 76.5% of companies in the Semiconductors industry.\n\nHowever, growth is a crucial factor in a company's valuation. NVIDIA's growth ranks worse than 52.99% of companies in the Semiconductors industry, with its 3-year average revenue growth rate better than 87.88% of companies in the industry.\n\nROIC vs WACC\nComparing a company's return on invested capital (ROIC) to its weighted average cost of capital (WACC) is an effective way to evaluate its profitability. Over the past 12 months, NVIDIA's ROIC was 20.32 while its W ...

# %%
type(loader)
# Out:
# langchain_community.document_loaders.text.TextLoader

# %%
loader.file_path
# Out:
# 'nvda_news_1.txt'

# %% [markdown]
# #### CSVLoader

# %%
from langchain_classic.document_loaders.csv_loader import CSVLoader

# %%
loader = CSVLoader(file_path="movies.csv")
data = loader.load()
data
# Out:
# [Document(metadata={'source': 'movies.csv', 'row': 0}, page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'),
#  Document(metadata={'source': 'movies.csv', 'row': 1}, page_content='movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'movies.csv', 'row': 2}, page_content='movie_id: 103\ntitle: Thor: The Dark World\nindustry: Hollywood\nrelease_year: 2013\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 165\nrevenue: 644.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'movies.csv', 'row': 3}, page_content='movie_id: 104\ntitle: Thor: Ragnarok\nindustry: Hollywood\nrelease_year: 2017\nimdb_rating: 7.9\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 180\nrevenue: 854\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'movies.csv', 'row': 4}, page_content='movie_id: 105\ntitle: Thor: Love and Thunder\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 250\nrevenue: 670\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'movies.csv', 'row': 5}, page_content='movie_id: 106\ntitle: Sholay\nindustry: Bollywood\nrelease_year: 1975\nimdb_rating: 8.1\nstudio: United Producers\nlanguage_id: 1\nbudget: Not Available\nrevenue: Not Available\nunit: Not Available\ncurrency: Not Available'),
#  Document(metadata={'source': 'movies.csv', 'row': 6}, page_content='movie_id: 107\ntitle: Dilwale Dulhania Le Jayenge\nindustry: Bollywood\nrelease_year: 1995\nimdb_rating: 8\nstudio: Yash Raj Films\nlanguage_id: 1\nbudget: 400\nrevenue: 2000\nunit: Millions\ncurrency: INR'),
#  Document(metadata={'source': 'movies.csv', 'row': 7}, page_content='movie_id: 108\ntitle: 3 Idiots\nindustry: Bollywood\nrelease_year: 2009\nimdb_rating: 8.4\nstudio: Vinod Chopra Films\nlanguage_id: 1\nbudget: 550\nrevenue: 4000\nunit: Millions\ncurrency: INR'),
#  Document(metadata={'source': 'movies.csv', 'row': 8}, page_content='movie_id: 109\ntitle: Kabhi Khushi Kabhie Gham\nindustry: Bollywood\nrelease_year: 2001\nimdb_rating: 7.4\nstudio: Dharma Productions\nlanguage_id: 1\nbudget: 390\nrevenue: 1360\nunit: Millions\ncurrency: INR')]

# %%
data[0]
# Out:
# Document(page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR', metadata={'source': 'movies.csv', 'row': 0})

# %%
loader = CSVLoader(file_path="movies.csv", source_column="title")
data = loader.load()
data
# Out:
# [Document(metadata={'source': 'K.G.F: Chapter 2', 'row': 0}, page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'),
#  Document(metadata={'source': 'Doctor Strange in the Multiverse of Madness', 'row': 1}, page_content='movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'Thor: The Dark World', 'row': 2}, page_content='movie_id: 103\ntitle: Thor: The Dark World\nindustry: Hollywood\nrelease_year: 2013\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 165\nrevenue: 644.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'Thor: Ragnarok', 'row': 3}, page_content='movie_id: 104\ntitle: Thor: Ragnarok\nindustry: Hollywood\nrelease_year: 2017\nimdb_rating: 7.9\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 180\nrevenue: 854\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'Thor: Love and Thunder', 'row': 4}, page_content='movie_id: 105\ntitle: Thor: Love and Thunder\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 250\nrevenue: 670\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'Sholay', 'row': 5}, page_content='movie_id: 106\ntitle: Sholay\nindustry: Bollywood\nrelease_year: 1975\nimdb_rating: 8.1\nstudio: United Producers\nlanguage_id: 1\nbudget: Not Available\nrevenue: Not Available\nunit: Not Available\ncurrency: Not Available'),
#  Document(metadata={'source': 'Dilwale Dulhania Le Jayenge', 'row': 6}, page_content='movie_id: 107\ntitle: Dilwale Dulhania Le Jayenge\nindustry: Bollywood\nrelease_year: 1995\nimdb_rating: 8\nstudio: Yash Raj Films\nlanguage_id: 1\nbudget: 400\nrevenue: 2000\nunit: Millions\ncurrency: INR'),
#  Document(metadata={'source': '3 Idiots', 'row': 7}, page_content='movie_id: 108\ntitle: 3 Idiots\nindustry: Bollywood\nrelease_year: 2009\nimdb_rating: 8.4\nstudio: Vinod Chopra Films\nlanguage_id: 1\nbudget: 550\nrevenue: 4000\nunit: Millions\ncurrency: INR'),
#  Document(metadata={'source': 'Kabhi Khushi Kabhie Gham', 'row': 8}, page_content='movie_id: 109\ntitle: Kabhi Khushi Kabhie Gham\nindustry: Bollywood\nrelease_year: 2001\nimdb_rating: 7.4\nstudio: Dharma Productions\nlanguage_id: 1\nbudget: 390\nrevenue: 1360\nunit: Millions\ncurrency: INR')]

# %%
data[0].page_content
# Out:
# 'movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'

# %%
data[0].metadata
# Out:
# {'source': 'K.G.F: Chapter 2', 'row': 0}

# %% [markdown]
# #### UnstructuredURLLoader

# %%
#installing necessary libraries, libmagic is used for file type detection
# !pip3 install unstructured libmagic python-magic python-magic-bin
# Out:
# Requirement already satisfied: unstructured in e:\document\news_genai\venv\lib\site-packages (0.21.5)
# Requirement already satisfied: libmagic in e:\document\news_genai\venv\lib\site-packages (1.0)
# Requirement already satisfied: python-magic in e:\document\news_genai\venv\lib\site-packages (0.4.27)
# Requirement already satisfied: python-magic-bin in e:\document\news_genai\venv\lib\site-packages (0.4.14)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.14.3 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (4.14.3)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.4.4 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (3.4.6)
# Requirement already satisfied: emoji<3.0.0,>=2.15.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: filelock<4.0.0,>=3.12.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (3.25.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: html5lib<2.0.0,>=1.1 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: installer<1.0.0,>=0.7.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (0.7.0)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: lxml<7.0.0,>=5.0.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (6.0.2)
# Requirement already satisfied: numba<1.0.0,>=0.60.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (0.64.0)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (2.4.3)
# Requirement already satisfied: psutil<8.0.0,>=7.2.2 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (7.2.2)
# Requirement already satisfied: python-iso639<2027.0.0,>=2026.1.31 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (2026.1.31)
# Requirement already satisfied: python-oxmsg<1.0.0,>=0.0.2 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.14.3 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (3.14.3)
# Requirement already satisfied: regex<2027.0.0,>=2024.0.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (2026.2.28)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (2.32.5)
# Requirement already satisfied: spacy<4.0.0,>=3.7.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (3.8.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.3 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (4.67.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.15.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (4.15.0)
# Requirement already satisfied: unstructured-client<1.0.0,>=0.25.9 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (0.42.10)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured) (1.17.3)
# Requirement already satisfied: soupsieve>=1.6.1 in e:\document\news_genai\venv\lib\site-packages (from beautifulsoup4<5.0.0,>=4.14.3->unstructured) (2.8.3)
# Requirement already satisfied: six>=1.9 in e:\document\news_genai\venv\lib\site-packages (from html5lib<2.0.0,>=1.1->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in e:\document\news_genai\venv\lib\site-packages (from html5lib<2.0.0,>=1.1->unstructured) (0.5.1)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in e:\document\news_genai\venv\lib\site-packages (from numba<1.0.0,>=0.60.0->unstructured) (0.46.0)
# Requirement already satisfied: click in e:\document\news_genai\venv\lib\site-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (8.3.1)
# Requirement already satisfied: olefile in e:\document\news_genai\venv\lib\site-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in e:\document\news_genai\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\document\news_genai\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->unstructured) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in e:\document\news_genai\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->unstructured) (2026.2.25)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (8.3.11)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (0.24.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.12.5)
# Requirement already satisfied: jinja2 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.1.6)
# Requirement already satisfied: setuptools in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in e:\document\news_genai\venv\lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (26.0)
# Requirement already satisfied: colorama in e:\document\news_genai\venv\lib\site-packages (from tqdm<5.0.0,>=4.67.3->unstructured) (0.4.6)
# Requirement already satisfied: aiofiles>=24.1.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (25.1.0)
# Requirement already satisfied: cryptography>=3.1 in e:\document\news_genai\venv\lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (46.0.5)
# Requirement already satisfied: httpcore>=1.0.9 in e:\document\news_genai\venv\lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (0.28.1)
# Requirement already satisfied: pypdf>=6.2.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (6.9.1)
# Requirement already satisfied: pypdfium2>=5.0.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (5.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\document\news_genai\venv\lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=2.0.0 in e:\document\news_genai\venv\lib\site-packages (from cryptography>=3.1->unstructured-client<1.0.0,>=0.25.9->unstructured) (2.0.0)
# Requirement already satisfied: h11>=0.16 in e:\document\news_genai\venv\lib\site-packages (from httpcore>=1.0.9->unstructured-client<1.0.0,>=0.25.9->unstructured) (0.16.0)
# Requirement already satisfied: anyio in e:\document\news_genai\venv\lib\site-packages (from httpx>=0.27.0->unstructured-client<1.0.0,>=0.25.9->unstructured) (4.12.1)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\document\news_genai\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.7.0->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\document\news_genai\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.7.0->unstructured) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\document\news_genai\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.7.0->unstructured) (0.4.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in e:\document\news_genai\venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: confection<1.1.0,>=0.0.1 in e:\document\news_genai\venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0.0,>=3.7.0->unstructured) (0.1.5)
# Requirement already satisfied: typer>=0.24.0 in e:\document\news_genai\venv\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.24.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in e:\document\news_genai\venv\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<4.0.0,>=3.7.0->unstructured) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in e:\document\news_genai\venv\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<4.0.0,>=3.7.0->unstructured) (7.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\document\news_genai\venv\lib\site-packages (from jinja2->spacy<4.0.0,>=3.7.0->unstructured) (3.0.3)
# Requirement already satisfied: pycparser in e:\document\news_genai\venv\lib\site-packages (from cffi>=2.0.0->cryptography>=3.1->unstructured-client<1.0.0,>=0.25.9->unstructured) (3.0)
# Requirement already satisfied: shellingham>=1.3.0 in e:\document\news_genai\venv\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in e:\document\news_genai\venv\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in e:\document\news_genai\venv\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\document\news_genai\venv\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\document\news_genai\venv\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in e:\document\news_genai\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.1.2)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_classic.document_loaders import UnstructuredURLLoader

# %%
loader = UnstructuredURLLoader(
    urls = [
        "https://www.moneycontrol.com/news/business/banks/hdfc-bank-re-appoints-sanmoy-chakrabarti-as-chief-risk-officer-11259771.html",
        "https://www.moneycontrol.com/news/business/markets/market-corrects-post-rbi-ups-inflation-forecast-icrr-bet-on-these-top-10-rate-sensitive-stocks-ideas-11142611.html"
    ]
)

# %%
data = loader.load()
len(data)
# Out:
# 2

# %%
data[0].page_content[0:100]
# Out:
# 'English\n\nHindi\n\nGujarati\n\nSpecials\n\nTrending Stocks\n\nIRFC\xa0INE053F01010, IRFC, 543257\n\nTata Power\xa0INE'

# %%
data[0].metadata
# Out:
# {'source': 'https://www.moneycontrol.com/news/business/banks/hdfc-bank-re-appoints-sanmoy-chakrabarti-as-chief-risk-officer-11259771.html'}

# %% [markdown]
# ## Text Splitters

# %%
# Taking some random text from wikipedia

text = """Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. 
It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. 
Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.

Brothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. 
Kip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. 
Cinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. 
Interstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.

Interstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. 
It has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades."""

# %% [markdown]
# #### Manual approach of splitting the text into chunks

# %%
# Say LLM token limit is 100, in that case we can do simple thing such as this

text[0:100]
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher N'

# %%
# Well but we want complete words and want to do this for entire text, may be we can use Python's split funciton

words = text.split(" ")
len(words)
# Out:
# 264

# %%
chunks = []

s = ""
for word in words:
    s += word + " "
    if len(s)>200:
        chunks.append(s)
        s = ""
        
chunks.append(s)

# %%
chunks[:2]
# Out:
# ['Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt ',
#  'Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in ']

# %%
from langchain_text_splitters import CharacterTextSplitter

splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size=200,
    chunk_overlap=0
)

# %%
chunks = splitter.split_text(text)
len(chunks)
# Out:
# Created a chunk of size 210, which is longer than the specified 200
# Created a chunk of size 208, which is longer than the specified 200
# Created a chunk of size 358, which is longer than the specified 200
# 9

# %%
for chunk in chunks:
    print(len(chunk))
# Out:
# 105
# 120
# 210
# 181
# 197
# 207
# 128
# 357
# 253

# %% [markdown]
# #### RecursiveTextSplitter

# %%
text
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.\n\nBrothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. \nKip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. \nCinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. \nInterstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.\n\nInterstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. \nIt has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades.'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

r_splitter = RecursiveCharacterTextSplitter(
    separators = ["\n\n", "\n", " "],  # List of separators based on requirement (defaults to ["\n\n", "\n", " "])
    chunk_size = 200,  # size of each chunk created
    chunk_overlap  = 0,  # size of  overlap between chunks in order to maintain the context
    length_function = len  # Function to calculate size, currently we are using "len" which denotes length of string however you can pass any token counter)
)

# %%
chunks = r_splitter.split_text(text)

for chunk in chunks:
    print(len(chunk))
# Out:
# 105
# 120
# 199
# 10
# 181
# 197
# 198
# 8
# 128
# 191
# 165
# 198
# 54

# %%
first_split = text.split("\n\n")[0]
first_split
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.'

# %%
len(first_split)
# Out:
# 439

# %% [markdown]
# Recursive text splitter uses a list of separators, i.e.  separators = ["\n\n", "\n", "."]
#
# So now it will first split using \n\n and then if the resulting chunk size is greater than the chunk_size parameter which is 200
# in our case, then it will use the next separator which is \n

# %%
second_split = first_split.split("\n")
second_split
# Out:
# ['Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. ',
#  'It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. ',
#  'Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.']

# %%
for split in second_split:
    print(len(split))
# Out:
# 106
# 121
# 210

# %% [markdown]
# Third split exceeds chunk size 200. Now it will further try to split that using the third separator which is ' ' (space)

# %%
second_split[2]
# Out:
# 'Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.'
